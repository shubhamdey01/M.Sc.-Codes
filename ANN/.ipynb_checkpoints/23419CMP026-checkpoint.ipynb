# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mean = 40
stDev = 20
val = np.random.normal(mean, stDev, 100000)
val = np.clip(val, 5, 95)

# %%
plt.hist(val, bins=50)
plt.show()

# %%
min(val), max(val)
# Out:
# (5.0, 95.0)

# %% [markdown]
# ## 1. Generate Marks

# %%
marks = np.random.normal(mean, stDev, (100000, 10))
marks = np.clip(marks, 5, 95)

# %%
marks.shape
# Out:
# (100000, 10)

# %%
result = np.random.rand(100000)
result = np.array(result > 0.5, dtype='int8')
result.shape
# Out:
# (100000,)

# %%
df = pd.DataFrame(marks, columns=[f'SUB-{i+1}' for i in range(10)])
df['Result'] = result
df.sample(5)
# Out:
#            SUB-1      SUB-2      SUB-3      SUB-4      SUB-5      SUB-6  \
# 57241  52.866439  35.962541  23.165670  58.509819  25.191444  54.004823
# 75732  48.326096  75.632969  68.255526  65.509583  47.693001  38.659283
# 63592  37.861282  32.483062   5.000000  62.359469  11.105043  34.150798
# 55142  21.408466  41.350288  23.599375  28.877547  30.473570  48.940735
# 68739  20.076415  19.573825  61.658312  48.462841  21.140744  14.667045
#
#            SUB-7      SUB-8      SUB-9     SUB-10  Result
# 57241  39.810884  34.595268  46.468258  29.573277       0
# 75732  50.064709  34.984625   5.000000  24.433955       1
# 63592  44.035580  16.207772  11.050793  33.699282       1
# 55142  23.618396  41.516388  39.172189  21.123956       1
# 68739  33.999660  66.685073  63.194306   5.000000       1

# %%
df['Result'].value_counts()
# Out:
# Result
# 0    50020
# 1    49980
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Plot Histogram

# %%
# Histogram for 10 subjects
plt.figure(figsize=(20, 20))
for i in range(10):
    plt.subplot(5, 2, i+1)
    plt.title(f'SUB-{i+1}')
    plt.hist(df[f'SUB-{i+1}'], bins=50)
plt.show()

# %% [markdown]
# ## 3. ANN Model

# %%
# spliting features & label
X = df.iloc[:, :2].values
Y = df.iloc[:, -1].values

# spliting train & test
xTrain, xTest = X[:80000, :], X[80000:, :]
yTrain, yTest = Y[:80000], X[80000:]

# %%
# initialize parameters
def initialize(ldims):
    inputLayer = ldims[0]
    hidden1 = ldims[1]
    hidden2 = ldims[2]
    hidden3 = ldims[3]
    outputLayer = ldims[4]

    params = {}
    params['W0'] = np.random.randn(hidden1, inputLayer)
    params['B0'] = np.random.randn(hidden1)
    params['W1'] = np.random.randn(hidden2, hidden1)
    params['B1'] = np.random.randn(hidden2)
    params['W2'] = np.random.randn(hidden3, hidden2)
    params['B2'] = np.random.randn(hidden3)
    params['W3'] = np.random.randn(outputLayer, hidden3)
    params['B3'] = np.random.randn(outputLayer)

    return params

# %%
# activation function
def sigmoid(x):
    # x = np.clip(x, -88.72, 88.72)
    return 1 / (1 + np.exp(-x))

# %%
# forward propagation
def forward(x, p):
    nnState = {}
    nnState['Z1'] = np.dot(p['W0'], x.T)
    nnState['A1'] = sigmoid(nnState['Z1'])
    nnState['Z2'] = np.dot(p['W1'], nnState['A1'])
    nnState['A2'] = sigmoid(nnState['Z2'])
    nnState['Z3'] = np.dot(p['W2'], nnState['A2'])
    nnState['A3'] = sigmoid(nnState['Z3'])
    nnState['Z4'] = np.dot(p['W3'], nnState['A3'])
    nnState['A4'] = sigmoid(nnState['Z3'])
    return nnState

# %%
# cost function
def cost(a, y):
    c = np.dot(y, np.log(a).T) + np.dot((1 - y), np.log(1 - a).T)
    return -c/y.shape[0]

# %%
# back propagation
def backPropagation(state, params, x, y):
    m = y.shape[0]
    
    dZ4 = state['A4'] - y
    dW4 = 1./m * np.dot(dZ4, state['A3'])
    dB4 = 1./m * np.sum(dZ4)

    dZ3 = np.dot(params['W3'].T, dZ4)
    dW3 = 1./m * np.dot(dZ3, state['A3'])
    dB3 = 1./m * np.sum(dZ3)

    dZ2 = np.dot(params['W2'].T, dZ3)
    dW2 = 1./m * np.dot(dZ2, state['A1'].T)
    dB2 = 1./m * np.sum(dZ2)

    dZ1 = np.dot(params['W1'].T, dZ2)
    dW1 = 1./m * np.dot(dZ1, x)
    dB1 = 1./m * np.sum(dZ1)

    return dW1, dB1, dW2, dB2, dW3, dB3, dW4, dB4

# %%
# prediction
def predict(x, params):
    res = forward(x, params)
    yPred = np.array(res['A4']>0.5, dtype='int8')
    return np.squeeze(yPred)

# %%
# main
l = [xTrain.shape[1], 15, 15, 15, 1]
params = initialize(l)
iters = 1000
lr = 0.01
t = []
c = []
a = []
for i in range(iters):
    nn = forward(xTrain, params)
    if i % (iters/10) == 0:
        t.append(i)
        c.append(cost(nn['A4'], yTrain))
        a.append(np.sum(predict(xTrain, params) == yTrain)/yTrain.shape[0])

    dW0, dB0, dW1, dB1, dW2, dB2, dW3, dB3 = backPropagation(nn, params, xTrain, yTrain)
    
    p['W0'] -= lr * dW0
    p['B0'] -= lr * dB0
    p['W1'] -= lr * dW1
    p['B1'] -= lr * dB1
    p['W2'] -= lr * dW2
    p['B2'] -= lr * dB2
    p['W3'] -= lr * dW3
    p['B3'] -= lr * dB3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 16
#      13     c.append(cost(nn['A4'], yTrain))
#      14     a.append(np.sum(predict(xTrain, params) == yTrain)/yTrain.shape[0])
# ---> 16 dW0, dB0, dW1, dB1, dW2, dB2, dW3, dB3 = backPropagation(nn, params, xTrain, yTrain)
#      18 p['W0'] -= lr * dW0
#      19 p['B0'] -= lr * dB0
#
# Cell In[110], line 6, in backPropagation(state, params, x, y)
#       3 m = y.shape[0]
#       5 dZ4 = state['A4'] - y
# ----> 6 dW4 = 1./m * np.dot(dZ4, state['A3'])
#       7 dB4 = 1./m * np.sum(dZ4)
#       9 dZ3 = np.dot(params['W3'].T, dZ4)
#
# ValueError: shapes (15,80000) and (15,80000) not aligned: 80000 (dim 1) != 15 (dim 0)

# %%
nn = forward(xTrain, params)

# %%
nn['A4'].shape
# Out:
# (15, 80000)

# %%
nn['A3'].shape
# Out:
# (15, 80000)
