# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Generate Marks and Assign Result

# %%
mean = 50
stDev = 15

# %%
marks = np.random.normal(mean, stDev, size=(100000, 10))
marks = np.clip(marks, 5, 95)
result = np.random.randint(2, size=(100000))

# %%
marks.shape, result.shape
# Out:
# ((100000, 10), (100000,))

# %%
np.min(marks), np.max(marks)
# Out:
# (5.0, 95.0)

# %%
df = pd.DataFrame(marks, columns=[f'SUB-{i+1}' for i in range(10)])
df['Result'] = result
df.head()
# Out:
#        SUB-1      SUB-2      SUB-3      SUB-4      SUB-5      SUB-6  \
# 0  65.190725  23.864943  33.972884  74.830241  62.778980  70.564732
# 1  43.966628  27.004767  73.193683  51.868200  53.098248  36.425082
# 2  56.669475  37.298574  63.399145  55.801417  49.922986  36.047900
# 3  49.303347  39.531744  48.309475  34.876027  49.205993  54.995086
# 4  69.385024  35.918571  31.812006  75.104712  79.630877  32.344819
#
#        SUB-7      SUB-8      SUB-9     SUB-10  Result
# 0  54.111118  56.057135  34.399570  68.800772       0
# 1  59.817472  56.919966  25.181132  29.218548       1
# 2  27.588897  57.031089  53.335012  46.930303       0
# 3  40.265274  26.854153  74.891905  35.448617       0
# 4  69.291931  63.076602  35.210601  51.401892       0

# %%
df.sample(5)
# Out:
#            SUB-1      SUB-2      SUB-3      SUB-4      SUB-5      SUB-6  \
# 6291   44.159181  51.628519  50.503465  32.150212  25.276501  41.977652
# 58953  56.644808  36.727762  50.788560  29.989380  65.843896  34.551803
# 7777   42.926017  50.262858  40.323912  58.438018  46.334835  76.924587
# 31761  34.324853  38.498198  51.435813  67.356456  73.030132  26.149449
# 24657  64.553482  80.562131  68.680699  56.432347  59.505031  58.523720
#
#            SUB-7      SUB-8      SUB-9     SUB-10  Result
# 6291   42.162902  45.028413  58.489274  42.346080       1
# 58953  39.879345  40.301925  38.077251  59.540863       0
# 7777   45.284770  55.282252  47.145415  45.522817       1
# 31761  42.418373  62.529727  32.911988  49.881055       0
# 24657  36.609943  59.670645  36.329284  49.754239       0

# %%
df['Result'].value_counts()
# Out:
# Result
# 1    50054
# 0    49946
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Plot histogram of each subject

# %%
plt.figure(figsize=(20, 30))
for i in range(10):
    plt.subplot(5, 2, i+1)
    plt.title(f'SUB-{i+1}')
    sns.histplot(df[f'SUB-{i+1}'], kde=True, bins=10)
plt.show()

# %% [markdown]
# ### 3. ANN Model

# %%
X = df.iloc[:, :10].values.reshape(10, 100000)
y = df.iloc[:, -1].values.reshape(1, 100000)

# %%
X.shape, y.shape
# Out:
# ((10, 100000), (1, 100000))

# %%
xTrain, xTest = X[:, :80000], X[:, 80000:]
yTrain, yTest = y[:, :80000], y[:, 80000:]

# %%
xTrain.shape, yTrain.shape
# Out:
# ((10, 80000), (1, 80000))

# %%
xTest.shape, yTest.shape
# Out:
# ((10, 20000), (1, 20000))

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def relu(z, dvt=False):
    if dvt:
        return 1. * (z > 0)
    return np.maximum(0, z)

# %%
def initializeParameters(ldims):
    L = len(ldims)
    params = {}
    for i in range(1, L):
        params[f'W{i}'] = np.random.uniform(size=(ldims[i], ldims[i-1]))
        params[f'b{i}'] = np.random.randn(ldims[i], 1)
    return params

# %%
def forwardPropagation(X, params):
    L = len(params) // 2
    cache = {}
    cache[f'A0'] = X
    for i in range(1, L):
        cache[f'Z{i}'] = np.dot(params[f'W{i}'], cache[f'A{i-1}']) + params[f'b{i}']
        cache[f'A{i}'] = relu(cache[f'Z{i}'])
    cache[f'Z{L}'] = np.dot(params[f'W{L}'], cache[f'A{L-1}']) + params[f'b{L}']
    cache[f'A{L}'] = sigmoid(cache[f'Z{L}'])

    return cache[f'A{L}'], cache

# %%
def costFunction(y, A):
    m = y.shape[1]
    cost = 1./m * (-np.dot(y, np.log(A).T) - np.dot((1 - y), np.log(1 - A).T))
    return np.squeeze(cost)

# %%
def backwardPropagation(A, y, params, cache):
    grads = {}
    L = len(params) // 2
    m = y.shape[1]
    
    grads[f'dZ{L}'] = A - y
    grads[f'dW{L}'] = 1./m * np.dot(grads[f'dZ{L}'], cache[f'A{L-1}'].T)
    grads[f'db{L}'] = 1./m * np.sum(grads[f'dZ{L}'], axis = 1, keepdims = True)
    
    for i in reversed(range(1, L)):
        grads[f'dZ{i}'] = np.dot(params[f'W{i+1}'].T, grads[f'dZ{i+1}']) * relu(cache[f'A{i}'], True)
        grads[f'dW{i}'] = 1./m * np.dot(grads[f'dZ{i}'], cache[f'A{i-1}'].T)
        grads[f'db{i}'] = 1./m * np.sum(grads[f'dZ{i}'], axis = 1, keepdims = True)
    return grads

# %%
def updateParameters(params, grads, lr):
    L = len(params) // 2
    for i in range(L):
        params[f'W{i+1}'] -= lr * grads[f'dW{i+1}']
        params[f'b{i+1}'] -= lr * grads[f'db{i+1}']
    return params

# %%
def predict(X, params):
    yPred, _ = forwardPropagation(X, params)
    yPred = 1 * (yPred > 0.5)
    return yPred

# %%
np.random.seed(10)

dims = [xTrain.shape[0], 15, 15, 15, yTrain.shape[0]]
params = initializeParameters(dims)
epocs = 200
lr = 0.1

time = []
cost = []
accuracy = []

for i in range(epocs):
    AL, cache = forwardPropagation(xTrain, params)
    if i % (epocs/10) == 0:
        time.append(i)
        cost.append(costFunction(yTrain, AL))
        accuracy.append(np.sum(predict(xTrain, params) == yTrain)/yTrain.shape[1])

    grads = backwardPropagation(AL, yTrain, params, cache)
    params = updateParameters(params, grads, lr)
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_12584\2519315829.py:3: RuntimeWarning: divide by zero encountered in log
#   cost = 1./m * (-np.dot(y, np.log(A).T) - np.dot((1 - y), np.log(1 - A).T))

# %%
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.title('Cost')
plt.plot(time, cost)

plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(time, accuracy)
plt.show()

# %%
# training accuracy
predTrain = predict(xTrain, params)
np.sum(predTrain == yTrain)/yTrain.shape[1]
# Out:
# 0.5001625

# %%
# testing accuracy
predTest = predict(xTest, params)
np.sum(predTest == yTest)/yTest.shape[1]
# Out:
# 0.49665
